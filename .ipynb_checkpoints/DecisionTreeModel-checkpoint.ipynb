# %%
import pandas as pd
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import math
import seaborn as sns
# %matplotlib inline

# %%
#Load Dataset and process it
train = pd.read_csv('data/cleaned_mostRecStat_train.csv',header=0,encoding='iso-8859-1')
train_y = train['is_placed']
train = train.drop("is_placed",1)


test = pd.read_csv('data/cleaned_mostRecStat_test.csv',header=0,encoding='iso-8859-1')
test_y = test['is_placed']
test = test.drop("is_placed",1)

print ("Features are : ", train.columns)
 = train.fillna(0.0)
print ("Dataset Target count: \n", train_y.value_counts())
# Out:
# Features are :  Index(['in_process', 'client_id', 'status_id', 'is_rockstar', 'candidate_id',
#        'recruiter_id', 'consulting', 'permanent', 'source_id',
#        'willingToRelocate', 'is_gmail', 'is_aol', 'is_custom', 'is_male',
#        'is_minority', 'is_ivy', 'yearsOfExp', 'is_citizen'],
#       dtype='object')
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-297bb679e0a8> in <module>()
#      10
#      11 print ("Features are : ", train.columns)
# ---> 12 df = df.fillna(0.0)
#      13 print ("Dataset Target count: \n", train_y.value_counts())
#
# NameError: name 'df' is not defined

# %%
#Train and Test data split
train = df.sample(frac=train_split)
print "Train dataset info:\n", train.y.value_counts()
test = df.loc[~df.index.isin(train.index)]
print "Test dataset info:\n", test.y.value_counts()
# Out:
# Train dataset info:
# 0    72680
# 1    16235
# Name: y, dtype: int64
# Test dataset info:
# 0    31309
# 1     6798
# Name: y, dtype: int64

# %%
#Modeling is done here
#Import relevant module for modelling.
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_graphviz
from sklearn.metrics import confusion_matrix,roc_auc_score

def testTrees(X_train,y_train,X_test,y_test,dep,leaf):
    clf = DecisionTreeClassifier(criterion='entropy',min_samples_leaf=leaf,max_depth=dep)
    clf = clf.fit(X_train,y_train)
    cm = confusion_matrix(clf.predict(X_test),y_test)
    accuracy = (cm[0][0]+cm[1][1])/float(len(X_test))
    misclass_rate = 1 - accuracy
    #print "Depth: %d, Leaf: %d, Misclassification Rate: %f, Accuracy: %f" %(dep,leaf,misclass_rate,accuracy)
    return roc_auc_score(y_test,clf.predict_proba(X_test)[:,1]), misclass_rate

# %%
depths=[10,15,20,30]
leaves=np.arange(1,150,5)
target = []
#Run all of the options
run=1
if (run==1):
    #Initialize dictionary of results
    res=dict()
    res2=dict()
    for d in depths:
        res[d]=list()
        res2[d]=list()

    #Now train and get results for each option
    for d in depths:
        for l in leaves:
            roc,mis = testTrees(train.drop('y',1),train['y'],test.drop('y',1),test['y'],d,l)
            res[d].append(roc)
            res2[d].append(mis)

# %%
#Plot Result           
fig = plt.figure()
ax=fig.add_subplot(111)
plt.plot(leaves,res[depths[0]],'b-',label='Depth={}'.format(depths[0]))
plt.plot(leaves,res[depths[1]],'r-',label='Depth={}'.format(depths[1]))
plt.plot(leaves,res[depths[2]],'y-',label='Depth={}'.format(depths[2]))
plt.plot(leaves,res[depths[3]],'g-',label='Depth={}'.format(depths[3]))
#plt.plot(leaves,res[depths[4]],'k-',label='Depth={}'.format(depths[4]))
plt.legend(loc=4)
ax.set_xlabel('Min Leaf Size')
ax.set_ylabel('Test Set AUC')
plt.title('Holdout AUC by Hyperparameters')

# %%
erate = 999
dep = 0
leaf_size = 0
for d in depths:
    print "Smallest error rate in depth %d is %f, leaf size is %d"%(d,min(res2[d]),leaves[np.argmin(res2[d])])
    if min(res2[d]) < erate:
        erate = min(res2[d])
        dep = d
        leaf_size = leaves[np.argmin(res2[d])]
# Out:
# Smallest error rate in depth 10 is 0.178786, leaf size is 111
# Smallest error rate in depth 15 is 0.179311, leaf size is 116
# Smallest error rate in depth 20 is 0.179311, leaf size is 116
# Smallest error rate in depth 30 is 0.179311, leaf size is 116

# %%
#Using the above result, focus on depth = 10, min leaf size=136
target_names = ['Fully Paid','Charged Off']
print "Optimal Depth: %d, Leaf Size: %d"%(dep,leaf_size)
clf = DecisionTreeClassifier(criterion='entropy',min_samples_leaf=leaf_size,max_depth=dep)
clf = clf.fit(train.drop('y',1),train['y'])
cm = confusion_matrix(clf.predict(test.drop('y',1)),test['y'])
cm = pd.DataFrame(cm, columns=target_names, index=target_names)
sns.heatmap(cm, annot=True)
plt.xlabel('true label')
plt.ylabel('predicted label');
plt.title('Confusion Matrix')

#Feature analysis
dt_features = clf.feature_importances_
cols = train.drop('y', 1).columns.values
fig, ax = plt.subplots()
width=0.5

sorted_index= np.argsort(dt_features)
topn = list(sorted_index[-20:])
topn.reverse()
print "\nTop 20 feature importance\n"
for i in topn:
    print cols[i], dt_features[i]
    
ax.bar(np.arange(len(cols[topn])), dt_features[topn], width, color='r', label='DT')
ax.set_xticks(np.arange(len(cols[topn])))
ax.set_xticklabels(cols[topn], rotation=90)
plt.title('Feature Importance from DT')
ax.set_ylabel('Normalized Gini Importance')
plt.legend(loc=1)
# Out:
# Optimal Depth: 10, Leaf Size: 111
#
# Top 20 feature importance
#
# int_rate 0.369449250096
# last_credit_pull_d_months 0.255607211693
# issue_d_months 0.121420042399
# annual_inc 0.0760322351974
# dti 0.0363433498659
# term_ 60 months 0.019764028167
# tot_cur_bal 0.015690293904
# installment 0.014264622129
# revol_bal 0.0138803182784
# loan_amnt 0.0129657147184
# zip_code_mod 0.0128765602798
# revol_util 0.0104638297605
# total_acc 0.00692802448664
# earliest_cr_line_months 0.00636960764133
# emp_length_mod 0.00593643241824
# total_rev_hi_lim 0.00399011360976
# inq_last_6mths 0.00387586148433
# open_acc 0.00370375949329
# home_ownership_MORTGAGE 0.00209163580872
# term_ 36 months 0.00189671307291
